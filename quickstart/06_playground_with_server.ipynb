# %%
from langserve import RemoteRunnable

remote_chain = RemoteRunnable("http://localhost:8000/agent/")
remote_chain.invoke({"input": "how can langsmith help with testing?"})
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/langserve/client.py:96, in _raise_for_status(response)
#      95 try:
# ---> 96     response.raise_for_status()
#      97 except httpx.HTTPStatusError as e:
#
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/httpx/_models.py:759, in Response.raise_for_status(self)
#     758 message = message.format(self, error_type=error_type)
# --> 759 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '422 Unprocessable Entity' for url 'http://localhost:8000/agent/invoke'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/422
#
# During handling of the above exception, another exception occurred:
#
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 from langserve import RemoteRunnable
#       3 remote_chain = RemoteRunnable("http://localhost:8000/agent/")
# ----> 4 remote_chain.invoke({"input": "how can langsmith help with testing?"})
#
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/langserve/client.py:295, in RemoteRunnable.invoke(self, input, config, **kwargs)
#     293 if kwargs:
#     294     raise NotImplementedError("kwargs not implemented yet.")
# --> 295 return self._call_with_config(self._invoke, input, config=config)
#
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/langchain_core/runnables/base.py:1235, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1231     context = copy_context()
#    1232     context.run(var_child_runnable_config.set, child_config)
#    1233     output = cast(
#    1234         Output,
# -> 1235         context.run(
#    1236             call_func_with_variable_args,
#    1237             func,  # type: ignore[arg-type]
#    1238             input,  # type: ignore[arg-type]
#    1239             config,
#    1240             run_manager,
#    1241             **kwargs,
#    1242         ),
#    1243     )
#    1244 except BaseException as e:
#    1245     run_manager.on_chain_error(e)
#
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/langchain_core/runnables/config.py:326, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     324 if run_manager is not None and accepts_run_manager(func):
#     325     kwargs["run_manager"] = run_manager
# --> 326 return func(input, **kwargs)
#
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/langserve/client.py:282, in RemoteRunnable._invoke(self, input, run_manager, config, **kwargs)
#     273 """Invoke the runnable with the given input and config."""
#     274 response = self.sync_client.post(
#     275     "/invoke",
#     276     json={
#    (...)
#     280     },
#     281 )
# --> 282 output, callback_events = _decode_response(
#     283     self._lc_serializer, response, is_batch=False
#     284 )
#     286 if self._use_server_callback_events and callback_events:
#     287     handle_callbacks(run_manager, callback_events)
#
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/langserve/client.py:169, in _decode_response(serializer, response, is_batch)
#     162 def _decode_response(
#     163     serializer: Serializer,
#     164     response: httpx.Response,
#     165     *,
#     166     is_batch: bool = False,
#     167 ) -> Tuple[Any, Union[List[CallbackEventDict], List[List[CallbackEventDict]]]]:
#     168     """Decode the response."""
# --> 169     _raise_for_status(response)
#     170     obj = response.json()
#     171     if not isinstance(obj, dict):
#
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/langserve/client.py:104, in _raise_for_status(response)
#     101 if e.response.text:
#     102     message += f" for {e.response.text}"
# --> 104 raise httpx.HTTPStatusError(
#     105     message=message,
#     106     request=_sanitize_request(e.request),
#     107     response=e.response,
#     108 )
#
# HTTPStatusError: Client error '422 Unprocessable Entity' for url 'http://localhost:8000/agent/invoke'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/422 for {"detail":[{"loc":["chat_history"],"msg":"field required","type":"value_error.missing"}]}
